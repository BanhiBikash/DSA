# %%
string name = "Banhi, Full Stack Dev";
Console.WriteLine("Hello, "+name+", welcome to Day 1 of DSA!");
# Out:
# Hello, Banhi, Full Stack Dev, welcome to Day 1 of DSA!

# %%
int[] arr = [1,2,3,4,5];
int check = 7;
List<int[]> result = new List<int[]>();

for(int i = 0;i<arr.Count();i++){
    for(int j=0; j<arr.Count();j++){
        if(arr[i]+arr[j]==check){
            result.Add([arr[i],arr[j]]);
        }
    }
}

if(result.Count==0){
    Console.WriteLine("No Pairs found");
}else{
    Console.WriteLine("The pairs are:");

    foreach(var pair in result){
        Console.WriteLine("\n"+pair[0]+" and "+pair[1]);
    }
}
# Out:
# The pairs are:
#
# 2 and 5
#
# 3 and 4
#
# 4 and 3
#
# 5 and 2
